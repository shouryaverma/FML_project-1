# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from collections import namedtuple, deque
import numpy as np
import pickle
import os
from typing import List

# %%
with open('Q_sa.npy', 'rb') as f:
    q_sa = np.load(f, allow_pickle=True)
q_sa = q_sa.tolist()

# %%
print(q_sa)
# Out:
# {0: {'UP': 3.9496253139359183, 'RIGHT': 2.399829462241039, 'DOWN': 3.017854704267031, 'LEFT': 3.6931285085018457, 'WAIT': -1.7023391270868802, 'BOMB': -0.007163824585694749}, 1: {'UP': -1.0064868680979957, 'RIGHT': -0.8048612237180254, 'DOWN': -0.9918232760801058, 'LEFT': 1.12050410217576, 'WAIT': -2.009329355728543, 'BOMB': -0.01052346323906211}, 2: {'UP': 0.019638873215139574, 'RIGHT': -0.019945627208125455, 'DOWN': -0.03270726740194296, 'LEFT': -0.006231811800748381, 'WAIT': -0.014385472656809199, 'BOMB': -0.019380819153797052}, 3: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 4: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 5: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 6: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 7: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 8: {'UP': 0.14297855447162733, 'RIGHT': 0.17674228981606527, 'DOWN': 0.45551289992267097, 'LEFT': 0.15127298971703315, 'WAIT': 0.4103376215849698, 'BOMB': 0.1}, 9: {'UP': 0.03283188751388448, 'RIGHT': 2.0255230483234925, 'DOWN': 21.353645216608076, 'LEFT': 0.040300171706084145, 'WAIT': 0.31226583092751364, 'BOMB': 0.1}, 10: {'UP': 0.19231942117964823, 'RIGHT': 0.30010385153654556, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1339456656210848, 'BOMB': 0.1}, 11: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 12: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 13: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 14: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 15: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 16: {'UP': -0.028422018166287193, 'RIGHT': -0.01999090612716433, 'DOWN': -0.0010354114990991708, 'LEFT': -0.0145615250734842, 'WAIT': -0.014294782295737146, 'BOMB': -0.03321207}, 17: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 18: {'UP': -0.01795016238990013, 'RIGHT': -0.004323117418260662, 'DOWN': -0.017864079716757995, 'LEFT': 0.030059066870716706, 'WAIT': -0.027813707990371576, 'BOMB': -0.02969578815925744}, 19: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 20: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 21: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 22: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 23: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 24: {'UP': 0.195, 'RIGHT': 0.14606946019169098, 'DOWN': 0.4455470527372305, 'LEFT': 0.16402103416276456, 'WAIT': 0.39271334567139016, 'BOMB': 0.1}, 25: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 26: {'UP': 0.19075791563945488, 'RIGHT': 0.2667777265370893, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.13265783826167507, 'BOMB': 0.1}, 27: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 28: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 29: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 30: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 31: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 32: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 33: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 34: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 35: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 36: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 37: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LEFT': 0.2, 'WAIT': 0.1, 'BOMB': 0.1}, 38: {'UP': 0.2, 'RIGHT': 0.2, 'DOWN': 0.2, 'LE ...
