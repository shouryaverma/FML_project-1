# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from collections import namedtuple, deque
import numpy as np
import pickle
import os
from typing import List

# %%
with open('Q_sa_2.npy', 'rb') as f:
    q_sa = np.load(f, allow_pickle=True)
q_sa = q_sa.tolist()

# %%
print(q_sa)
# Out:
# {0: {'UP': 0.025885268940004803, 'RIGHT': 0.026541220511321757, 'DOWN': 0.026248078923986916, 'LEFT': 0.026552488184777512, 'WAIT': 0.022564703734959453, 'BOMB': 0.01048627229492401}, 1: {'UP': 0.02668581625561281, 'RIGHT': 0.02654391328382872, 'DOWN': 0.02193087991703492, 'LEFT': 0.02289269219798543, 'WAIT': 0.02160058823988616, 'BOMB': 0.024457563611750128}, 2: {'UP': 0.02572863302407789, 'RIGHT': 0.025860113439493154, 'DOWN': -429.09194043120317, 'LEFT': 0.030826946092657723, 'WAIT': 0.025636796907978366, 'BOMB': 0}, 3: {'UP': 0.02792737321613866, 'RIGHT': 0.027274430606674078, 'DOWN': 0, 'LEFT': 0.021707858715212008, 'WAIT': 0.022817451344184267, 'BOMB': 0.026642358918588835}, 4: {'UP': 0.035681927646637704, 'RIGHT': 0.02647328644322571, 'DOWN': -0.05243465775366667, 'LEFT': 0.029808211147568053, 'WAIT': 0.021457231117198657, 'BOMB': 0}, 5: {'UP': 0.0227805584818095, 'RIGHT': 0.019675034353897437, 'DOWN': 0, 'LEFT': 0.022994340863716125, 'WAIT': 0.023444237494013743, 'BOMB': 0.03
# ...
